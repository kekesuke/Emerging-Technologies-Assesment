# %% [markdown]
# # The Numpy Random Package
# [Official documentation ](https://numpy.org/doc/stable/reference/random/index.html)
# ***

# %%
#Numpy efficiant numerical arrays
import numpy as np
#Plotting
import matplotlib.pyplot as plt

# %%
#Change the default style sheet
plt.style.use('fivethirtyeight')
#Change the default figure size
plt.rcParams['figure.figsize'] = [12, 6]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
#look at first 10 items
s[:10]
# Out:
# array([ 0.05860636,  0.09906938,  0.08362747,  0.04009753, -0.08249808,
#         0.03262092, -0.12781619, -0.02822614,  0.12235502,  0.02978273])

# %%
abs(mu - np.mean(s))
# Out:
# 0.0022741893367782657

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0021856100364993913

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-(bins-mu)**2 / (2 *sigma**2))
plt.plot(bins, f, linewidth=2)
plt.show()

# %% [markdown]
# ## References
# [1]. https://www.datacamp.com/community/tutorials/numpy-random
# [2]. https://numpy.org/doc/stable/reference/random/index.html

# %% [markdown]
# ***
# ## End
